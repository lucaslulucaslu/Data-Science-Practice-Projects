# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#https://statso.io/user-profiling-case-study/
data=pd.read_csv(r'''..\datasets\14-User-Profiling-Segementation\user_profiles_for_ads.csv''')

# %%
data.head()
# Out:
#    User ID    Age  Gender  Location Language Education Level  \
# 0        1  25-34  Female  Suburban    Hindi       Technical
# 1        2    65+    Male     Urban    Hindi             PhD
# 2        3  45-54  Female  Suburban  Spanish       Technical
# 3        4  35-44  Female     Rural  Spanish             PhD
# 4        5  25-34  Female     Urban  English       Technical
#
#    Likes and Reactions  Followed Accounts  Device Usage  \
# 0                 5640                190   Mobile Only
# 1                 9501                375        Tablet
# 2                 4775                187   Mobile Only
# 3                 9182                152  Desktop Only
# 4                 6848                371   Mobile Only
#
#    Time Spent Online (hrs/weekday)  Time Spent Online (hrs/weekend)  \
# 0                              4.5                              1.7
# 1                              0.5                              7.7
# 2                              4.5                              5.6
# 3                              3.1                              4.2
# 4                              2.0                              3.8
#
#    Click-Through Rates (CTR)  Conversion Rates  Ad Interaction Time (sec)  \
# 0                      0.193             0.067                         25
# 1                      0.114             0.044                         68
# 2                      0.153             0.095                         80
# 3                      0.093             0.061                         65
# 4                      0.175             0.022                         99
#
#   Income Level                                      Top Interests
# 0      20k-40k                                  Digital Marketing
# 1        0-20k                                       Data Science
# 2      60k-80k                               Fitness and Wellness
# 3        100k+                                 Gaming, DIY Crafts
# 4      20k-40k  Fitness and Wellness, Investing and Finance, G...

# %%
data.isnull().sum()
# Out:
# User ID                            0
# Age                                0
# Gender                             0
# Location                           0
# Language                           0
# Education Level                    0
# Likes and Reactions                0
# Followed Accounts                  0
# Device Usage                       0
# Time Spent Online (hrs/weekday)    0
# Time Spent Online (hrs/weekend)    0
# Click-Through Rates (CTR)          0
# Conversion Rates                   0
# Ad Interaction Time (sec)          0
# Income Level                       0
# Top Interests                      0
# dtype: int64

# %%
fig,axes=plt.subplots(nrows=3,ncols=2,figsize=(10,9))
data['Age'].value_counts().plot(kind='bar',ax=axes[0,0])
axes[0,0].tick_params(axis='x',rotation=0)
axes[0,0].set_ylabel('Count')
axes[0,0].set_title('Age distribution')

data['Gender'].value_counts().plot(kind='pie',explode=(0.1,0),autopct='%1.1f%%',ylabel='Count',ax=axes[0,1])

data['Education Level'].value_counts().plot(kind='bar',ax=axes[1,0])
axes[1,0].tick_params(axis='x',rotation=15)
axes[1,0].set_ylabel('Count')
axes[1,0].set_title('Education level distribution')

data['Device Usage'].value_counts().plot(kind='bar',ax=axes[1,1])
axes[1,1].tick_params(axis='x',rotation=15)
axes[1,1].set_ylabel('Count')
axes[1,1].set_title('Device Usage distribution')

data['Income Level'].value_counts().plot(kind='bar',ax=axes[2,0])
axes[2,0].tick_params(axis='x',rotation=15)
axes[2,0].set_ylabel('Count')
axes[2,0].set_title('Income level distribution')

data['Language'].value_counts().plot(kind='bar',ax=axes[2,1])
axes[2,1].tick_params(axis='x',rotation=15)
axes[2,1].set_ylabel('Count')
axes[2,1].set_title('Language distribution')

plt.tight_layout()
plt.show()

# %%
import warnings
warnings.filterwarnings( "ignore", module = "seaborn\..*" )
fig, axes = plt.subplots(3, 2, figsize=(12, 9))
fig.suptitle('User Online Behavior and Ad Interaction Metrics')

# time spent online on weekdays
sns.histplot(ax=axes[0, 0], x='Time Spent Online (hrs/weekday)', data=data, bins=20, kde=True, color='skyblue')
axes[0, 0].set_title('Time Spent Online on Weekdays')

# time spent online on weekends
sns.histplot(ax=axes[0, 1], x='Time Spent Online (hrs/weekend)', data=data, bins=20, kde=True, color='orange')
axes[0, 1].set_title('Time Spent Online on Weekends')

# likes and reactions
sns.histplot(ax=axes[1, 0], x='Likes and Reactions', data=data, bins=20, kde=True, color='green')
axes[1, 0].set_title('Likes and Reactions')

# click-through rates
sns.histplot(ax=axes[1, 1], x='Click-Through Rates (CTR)', data=data, bins=20, kde=True, color='red')
axes[1, 1].set_title('Click-Through Rates (CTR)')

# conversion rates
sns.histplot(ax=axes[2, 0], x='Conversion Rates', data=data, bins=20, kde=True, color='purple')
axes[2, 0].set_title('Conversion Rates')

# ad interaction time
sns.histplot(ax=axes[2, 1], x='Ad Interaction Time (sec)', data=data, bins=20, kde=True, color='brown')
axes[2, 1].set_title('Ad Interaction Time (sec)')

plt.tight_layout()
plt.show()

# %%
data.head()
# Out:
#    User ID    Age  Gender  Location Language Education Level  \
# 0        1  25-34  Female  Suburban    Hindi       Technical
# 1        2    65+    Male     Urban    Hindi             PhD
# 2        3  45-54  Female  Suburban  Spanish       Technical
# 3        4  35-44  Female     Rural  Spanish             PhD
# 4        5  25-34  Female     Urban  English       Technical
#
#    Likes and Reactions  Followed Accounts  Device Usage  \
# 0                 5640                190   Mobile Only
# 1                 9501                375        Tablet
# 2                 4775                187   Mobile Only
# 3                 9182                152  Desktop Only
# 4                 6848                371   Mobile Only
#
#    Time Spent Online (hrs/weekday)  Time Spent Online (hrs/weekend)  \
# 0                              4.5                              1.7
# 1                              0.5                              7.7
# 2                              4.5                              5.6
# 3                              3.1                              4.2
# 4                              2.0                              3.8
#
#    Click-Through Rates (CTR)  Conversion Rates  Ad Interaction Time (sec)  \
# 0                      0.193             0.067                         25
# 1                      0.114             0.044                         68
# 2                      0.153             0.095                         80
# 3                      0.093             0.061                         65
# 4                      0.175             0.022                         99
#
#   Income Level                                      Top Interests
# 0      20k-40k                                  Digital Marketing
# 1        0-20k                                       Data Science
# 2      60k-80k                               Fitness and Wellness
# 3        100k+                                 Gaming, DIY Crafts
# 4      20k-40k  Fitness and Wellness, Investing and Finance, G...

# %%
interests=pd.DataFrame(data['Top Interests'].str.split(',').sum(),columns=['Interest']).value_counts().head(10).reset_index()

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=interests,x='count',y='Interest')
plt.title('Top 10 User Interests')
plt.xlabel('Frequency')
plt.ylabel('Interest')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.cluster import KMeans

# %%
X=data[['Age', 'Gender', 'Income Level', 'Time Spent Online (hrs/weekday)', 'Time Spent Online (hrs/weekend)', 'Likes and Reactions', 'Click-Through Rates (CTR)']]

# %%
numeric_features = ['Time Spent Online (hrs/weekday)', 'Time Spent Online (hrs/weekend)', 'Likes and Reactions', 'Click-Through Rates (CTR)']
X_numeric=X[numeric_features]
categorical_features = ['Age', 'Gender', 'Income Level']
X_category=X[categorical_features]

# %%
scaler=StandardScaler()
scaler.fit(X_numeric)
# Out:
# StandardScaler()

# %%
X_numeric_scaled=scaler.transform(X_numeric)

# %%
onehot=OneHotEncoder(sparse_output=False)
onehot.fit(X_category)
# Out:
# OneHotEncoder(sparse_output=False)

# %%
X_category_onehot=onehot.transform(X_category)

# %%
processed_data=np.concatenate((X_numeric_scaled,X_category_onehot),axis=1)

# %%
kmeans=KMeans(n_clusters=5,random_state=42)

# %%
kmeans.fit(processed_data)
# Out:
# C:\Users\shich\anaconda3\envs\datascience\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# KMeans(n_clusters=5, random_state=42)

# %%
data['cluster']=kmeans.labels_

# %%
data.head()
# Out:
#    User ID    Age  Gender  Location Language Education Level  \
# 0        1  25-34  Female  Suburban    Hindi       Technical
# 1        2    65+    Male     Urban    Hindi             PhD
# 2        3  45-54  Female  Suburban  Spanish       Technical
# 3        4  35-44  Female     Rural  Spanish             PhD
# 4        5  25-34  Female     Urban  English       Technical
#
#    Likes and Reactions  Followed Accounts  Device Usage  \
# 0                 5640                190   Mobile Only
# 1                 9501                375        Tablet
# 2                 4775                187   Mobile Only
# 3                 9182                152  Desktop Only
# 4                 6848                371   Mobile Only
#
#    Time Spent Online (hrs/weekday)  Time Spent Online (hrs/weekend)  \
# 0                              4.5                              1.7
# 1                              0.5                              7.7
# 2                              4.5                              5.6
# 3                              3.1                              4.2
# 4                              2.0                              3.8
#
#    Click-Through Rates (CTR)  Conversion Rates  Ad Interaction Time (sec)  \
# 0                      0.193             0.067                         25
# 1                      0.114             0.044                         68
# 2                      0.153             0.095                         80
# 3                      0.093             0.061                         65
# 4                      0.175             0.022                         99
#
#   Income Level                                      Top Interests  cluster
# 0      20k-40k                                  Digital Marketing        2
# 1        0-20k                                       Data Science        1
# 2      60k-80k                               Fitness and Wellness        0
# 3        100k+                                 Gaming, DIY Crafts        3
# 4      20k-40k  Fitness and Wellness, Investing and Finance, G...        2

# %% [markdown]
# #re do with pipeline method

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.cluster import KMeans

# selecting features for clustering
features = ['Age', 'Gender', 'Income Level', 'Time Spent Online (hrs/weekday)', 'Time Spent Online (hrs/weekend)', 'Likes and Reactions', 'Click-Through Rates (CTR)']

# separating the features we want to consider for clustering
X = data[features]

# defining preprocessing for numerical and categorical features
numeric_features = ['Time Spent Online (hrs/weekday)', 'Time Spent Online (hrs/weekend)', 'Likes and Reactions', 'Click-Through Rates (CTR)']
numeric_transformer = StandardScaler()

categorical_features = ['Age', 'Gender', 'Income Level']
categorical_transformer = OneHotEncoder()

# combining preprocessing steps
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# creating a preprocessing and clustering pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('cluster', KMeans(n_clusters=5, random_state=42))])

pipeline.fit(X)
cluster_labels = pipeline.named_steps['cluster'].labels_
data['Cluster'] = cluster_labels

print(data.head())
# Out:
#    User ID    Age  Gender  Location Language Education Level  \
# 0        1  25-34  Female  Suburban    Hindi       Technical
# 1        2    65+    Male     Urban    Hindi             PhD
# 2        3  45-54  Female  Suburban  Spanish       Technical
# 3        4  35-44  Female     Rural  Spanish             PhD
# 4        5  25-34  Female     Urban  English       Technical
#
#    Likes and Reactions  Followed Accounts  Device Usage  \
# 0                 5640                190   Mobile Only
# 1                 9501                375        Tablet
# 2                 4775                187   Mobile Only
# 3                 9182                152  Desktop Only
# 4                 6848                371   Mobile Only
#
#    Time Spent Online (hrs/weekday)  Time Spent Online (hrs/weekend)  \
# 0                              4.5                              1.7
# 1                              0.5                              7.7
# 2                              4.5                              5.6
# 3                              3.1                              4.2
# 4                              2.0                              3.8
#
#    Click-Through Rates (CTR)  Conversion Rates  Ad Interaction Time (sec)  \
# 0                      0.193             0.067                         25
# 1                      0.114             0.044                         68
# 2                      0.153             0.095                         80
# 3                      0.093             0.061                         65
# 4                      0.175             0.022                         99
#
#   Income Level                                      Top Interests  cluster  \
# 0      20k-40k                                  Digital Marketing        2
# 1        0-20k                                       Data Science        1
# 2      60k-80k                               Fitness and Wellness        0
# 3        100k+                                 Gaming, DIY Crafts        3
# 4      20k-40k  Fitness and Wellness, Investing and Finance, G...        2
#
#    Cluster
# 0        2
# 1        1
# 2        0
# 3        3
# 4        2
# C:\Users\shich\anaconda3\envs\datascience\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %%
cluster_means = data.groupby('cluster')[numeric_features].mean()
for feature in categorical_features:
    mode_series = data.groupby('cluster')[feature].agg(lambda x: x.mode()[0])
    cluster_means[feature] = mode_series

print(cluster_means)
# Out:
#          Time Spent Online (hrs/weekday)  Time Spent Online (hrs/weekend)  \
# cluster
# 0                               3.911111                         5.212963
# 1                               1.559394                         6.002424
# 2                               3.019737                         2.584211
# 3                               3.080882                         5.774510
# 4                               1.809626                         3.839572
#
#          Likes and Reactions  Click-Through Rates (CTR)    Age  Gender  \
# cluster
# 0                2409.620370                   0.149588  25-34  Female
# 1                5005.121212                   0.179836  35-44    Male
# 2                6861.587719                   0.170614  25-34    Male
# 3                7457.602941                   0.067971  25-34  Female
# 4                3021.219251                   0.056594  45-54  Female
#
#         Income Level
# cluster
# 0           80k-100k
# 1           80k-100k
# 2            20k-40k
# 3              100k+
# 4              0-20k

# %%
cluster_means
# Out:
#          Time Spent Online (hrs/weekday)  Time Spent Online (hrs/weekend)  \
# cluster
# 0                               3.911111                         5.212963
# 1                               1.559394                         6.002424
# 2                               3.019737                         2.584211
# 3                               3.080882                         5.774510
# 4                               1.809626                         3.839572
#
#          Likes and Reactions  Click-Through Rates (CTR)    Age  Gender  \
# cluster
# 0                2409.620370                   0.149588  25-34  Female
# 1                5005.121212                   0.179836  35-44    Male
# 2                6861.587719                   0.170614  25-34    Male
# 3                7457.602941                   0.067971  25-34  Female
# 4                3021.219251                   0.056594  45-54  Female
#
#         Income Level
# cluster
# 0           80k-100k
# 1           80k-100k
# 2            20k-40k
# 3              100k+
# 4              0-20k

# %%
cluster_means_normal=(cluster_means[labels]-cluster_means[labels].mean())/(cluster_means[labels].max()-cluster_means[labels].min())

# %%
labels=['Time Spent Online (hrs/weekday)','Time Spent Online (hrs/weekend)','Likes and Reactions','Click-Through Rates (CTR)']

# %%
fig=plt.figure()
ax = fig.add_subplot(111, polar=True)
for i in range(5):
    stats=cluster_means_normal.loc[i,labels].values
    angles=np.linspace(0, 2*np.pi, len(labels), endpoint=False)
    # close the plot
    stats=np.concatenate((stats,[stats[0]]))
    angles=np.concatenate((angles,[angles[0]]))
    
    ax.plot(angles, stats, 'o-', linewidth=2,label=i)
    ax.fill(angles, stats, alpha=0.25)
    ax.set_thetagrids(angles[:-1] * 180/np.pi, labels)
    ax.grid(True)
plt.legend()
plt.show()
